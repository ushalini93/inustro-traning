# %% [markdown]
# <a href="https://colab.research.google.com/github/ushalini93/inustro-traning/blob/main/Llms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.generativeai import GenerativeModel, configure
configure(api_key="AIzaSyBOIojVzOZF1sTBnb0pjKdRtFTXatN9W9c")
model = GenerativeModel("gemini-1.5-pro")
r = model.generate_content("Who are you?")
print(r.text)
# Out:
# I am a large language model, trained by Google.

# %%
from google.generativeai import GenerativeModel, configure
configure(api_key="AIzaSyBOIojVzOZF1sTBnb0pjKdRtFTXatN9W9c")
model = GenerativeModel("gemini-1.5-pro")
print("Welcome to AI Chatbot! Type 'exit' to stop.")
while True:
     user_input = input("You: ")
     if user_input.lower() == "exit":
         break
     response = model.generate_content(user_input)
     print("AI:", response.text)
# Out:
# Welcome to AI Chatbot! Type 'exit' to stop.
# AI: Hi there! How can I help you today?
#
# AI: I'm doing well, thank you for asking! How are you today?
#
# AI: "Ushalini" is a name primarily found in Indian cultures, especially South Indian.  While definitive meanings can vary based on region and linguistic nuances, it is generally understood to relate to the dawn or early morning.
#
# Here's a breakdown of potential interpretations:
#
# * **Usha (उषा):**  The Sanskrit word "Usha" refers to dawn, the reddish glow in the sky before sunrise.  It's often personified as a goddess of dawn in Hindu mythology.
#
# * **-lini (लिनी):** This suffix can indicate possession, resemblance, or characteristic.  Therefore, "Ushalini" can be understood as "possessing the qualities of dawn,"  "resembling the dawn," or "one who belongs to the dawn."
#
# Putting it together, "Ushalini" can evoke several beautiful connotations:
#
# ...

# %%
from deep_translator import GoogleTranslator
def translate_text(text, target_language):
    translator = GoogleTranslator(source='auto', target=target_language)
    return translator.translate(text)
text = "Hello, how are you?"
target_language = "ta"

translated_text = translate_text(text, target_language)
print(f"Original: {text}")
print(f"Translated ({target_language}): {translated_text}")
# Out:
# Original: Hello, how are you?
# Translated (ta): வணக்கம், நீங்கள் எப்படி இருக்கிறீர்கள்?

# %%
pip install deep_translator
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.8 MB/s eta 0:00:00
# ...
